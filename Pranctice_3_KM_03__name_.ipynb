# %% [markdown]
# # **Курс "Програмування на мові Python"**
#
# ##### Викладачі:
# ##### Борисенко Павло Борисович
# ##### Щьоголєв Максим Олегович

# %% [markdown]
# ## **Практичне зайняття №3**
# ### Тема: "Перші програми на Python. Введення та виведення даних. Інструкція if"

# %% [markdown]
# ### **Завдання 1 (1,5 бали)**

# %% [markdown]
# **Написати програму введення та виведення даних про одержувача листа (посилки) за стандартами Укрпошти.**
#
# 1. Усі запити на введення даних повинні супроводжуватись відповідними підказками-поясненнями (бажано англійською мовою).
#
# 2. Дані мають виводитись так, як показано нижче (з урахуванням кількості рядків та послідовності даних у кожному з них).
#
# 3. Дані, виділені жирним шрифтом, повинні вводитись із клавіатури. Всього має бути 9 окремих команд введення даних
#
# 4. Назви змінних повинні бути інформативними та оформленими відповідно до правил іменування змінних
#
# 5. Додати 2 коментарі, що вказують на блоки введення та виведення даних.
#
# ***Формат виведення даних:***
#
# (1) **Ім'я** (2) **Прізвище**
#
# (3) **Номер телефону**
#
# Str. (4) **Назва вулиці** (5) **Номер будинку**, ap. (6) **Номер квартири**, (7) **Місто**
#
# (8) **Індекс**
#
# (9) **Країна**

# %%
print('Дані про одержувача листа (посилки) за стандартами України:')
#вводимо дані за допомогою команди input
a = (input('Ім*я:' ))
b =  int(input('Номер телефону:'))
c = (input('Назва вулиці:')) 
g = int(input('Номер будинку:' )) 
j = int(input('Номер квартири:' )) 
l = (input('Місто:' ))
d =  int(input('Індекс:'))
h = (input('Країна:'))
#ввиводимо дані за допомогою команди print
print(a)
print(b)
print("Str:", c, g, j, l)
print(d)
print(h)
# Out:
# Дані про одержувача листа (посилки) за стандартами України:
# alian
# 8764
# Str: fd 2 3 gfd
# 3435
# fvdf

# %% [markdown]
# ### **Завдання 2 (1,5 бали)**

# %% [markdown]
# Відповідно до чинної системи оцінювання в КПІ, рейтингові бали R студентів переводяться в оцінки за такою таблицею:
#
# R | Grade
# --- | ---
# 95 - 100 | Excellent
# 85 - 94 | Very good
# 75 - 84 | Good
# 65 - 74 | Satisfactory
# 60 - 64 | Marginal
# 0 - 59 | Unsatisfactory
#
# Напишіть програму, яка буде зчитувати рейтинговий бал R, введений користувачем, та виводити відповідну оцінку як частину змістовного повідомлення. Наприклад, якщо користувач вводить рейтинговий бал R 78, ваша програма повинна показати оцінку Good. Програма також повинна виводити повідомлення про помилку, якщо користувач введе від'ємне число або число, більше за 100.

# %%
print('Введіть бал свій (R):')
#за допомогою команд print/ input вказуємо умову і вводимо
a = int(input())
#за допомогою команди if ставимо умову
if 0 <= a <= 59:
    print('Unsatisfactory')
if  60 <= a <= 64:
    print('Marginal')
if 65 <= a <= 74:
    print('Satisfactory')
if  75 <= a <= 84:
    print(' Good')
if 85 <= a <= 94:
    print('Very good')
if 95 <= a <= 100:
    print('Excellent')
print('Bye')
# Out:
# Введіть бал свій (R):
# Excellent
# Bye

# %% [markdown]
# ### **Завдання 3 (бонусне, 1 бал)**

# %% [markdown]
# Мобільний оператор розробив тарифний план, згідно з яким, сплачуючи 100 грн. на місяць, абонент може спілкуватись 50 хвилин з абонентами інших мобільних операторів впродовж цього місяця. У разі перевищення ліміту абоненту надаються ще 50 хвилин до кінця місяця за 50 грн. Якщо ж і цей ліміт було перевищено, абонент сплачуватиме 2 грн. за кожну додаткову хвилину розмов до кінця поточного місяця.
#
# Напишіть програму, що підраховує суму коштів, яку доведеться сплатити абоненту за місяць, на основі тривалості його розмов з абонентами інших мобільних операторів (у хвилинах), введеної користувачем з клавіатури. Ваша програма також повинна виводити повідомлення про помилку, якщо користувач введе від'ємне число.

# %%
print('Введіть скільки хвилин ви розмовляли по тлефону цього місяця:')
a = 100
b = int(input())
if b <= 0:
    print('Ops!Only positive numbers.')
if 100 <= b < 0:
    print('Ваша сума оплати за умовами тарифу:')
    print(a + 50)
if b < 100:
    print('Ваша сума оплати за умовами тарифу:')
    print(100)
if b > 150:
    sum = 0
    temple = 0
    c = b-150
    for i in range(1, c + 1):
        temple = (c + 2)
        sum += temple
    print('Ваша сума оплати за умовами тарифу:')
    print(sum+a)
# Out:
# Введіть скільки хвилин ви розмовляли по тлефону цього місяця:
# 100
# Ваша сума оплати за умовами тарифу:
